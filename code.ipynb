# %% [markdown]
# ## Preliminary Project 1 Notebook
# Note: It needs more data formatting for final report

# %% [markdown]
# #### Import Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# #### Loading Data

# %%
sat17_df = pd.read_csv('data/sat_2017.csv')
sat18_df = pd.read_csv('data/sat_2018.csv')
sat19_df = pd.read_csv('data/sat_2019.csv')
act17_df = pd.read_csv('data/act_2017.csv')
act18_df = pd.read_csv('data/act_2018.csv')
act19_df = pd.read_csv('data/act_2019.csv')
state_region_df = pd.read_csv('data/us_state_region.csv')

sat17_df['Year'] = 2017
sat17_df['Type'] = 'SAT'
sat18_df['Year'] = 2018
sat18_df['Type'] = 'SAT'
sat19_df['Year'] = 2019
sat19_df['Type'] = 'SAT'

act17_df['Year'] = 2017
act17_df['Type'] = 'ACT'
act18_df['Year'] = 2018
act18_df['Type'] = 'ACT'
act19_df['Year'] = 2019
act19_df['Type'] = 'ACT'


exam_df = pd.concat([sat17_df, sat18_df, sat19_df, act17_df, act18_df, act19_df], ignore_index=True)

# %% [markdown]
# ### Data Exploration

# %%
# review sample data
for year, type in [[2017, 'SAT'], [2018, 'SAT'], [2019, 'SAT'], [2017, 'ACT'], [2018, 'ACT'], [2019, 'ACT']]:
    print(f"Year:{year}, Type:{type} Shape:{exam_df[(exam_df['Year']==year) & (exam_df['Type']==type)].shape}")
    print("* Review Sample Data")
    print(exam_df[(exam_df['Year']==year) & (exam_df['Type']==type)].head(5))
    print("\n* Review NULL Data")
    print(exam_df[(exam_df['Year']==year) & (exam_df['Type']==type)].isna().sum())
    print("\n* Review data type")
    print(exam_df[(exam_df['Year']==year) & (exam_df['Type']==type)].dtypes)
    print('-' * 80, '\n')
# Out:
# Year:2017, Type:SAT Shape:(51, 13)
# * Review Sample Data
#         State Participation  Evidence-Based Reading and Writing   Math  \
# 0     Alabama            5%                               593.0  572.0
# 1      Alaska           38%                               547.0  533.0
# 2     Arizona           30%                               563.0  553.0
# 3    Arkansas            3%                               614.0  594.0
# 4  California           53%                               531.0  524.0
#
#     Total  Year Type Participation  Evidence-Based Reading and Writing  \
# 0  1165.0  2017  SAT           NaN                                 NaN
# 1  1080.0  2017  SAT           NaN                                 NaN
# 2  1116.0  2017  SAT           NaN                                 NaN
# 3  1208.0  2017  SAT           NaN                                 NaN
# 4  1055.0  2017  SAT           NaN                                 NaN
#
#    English  Reading  Science Composite
# 0      NaN      NaN      NaN       NaN
# 1      NaN      NaN      NaN       NaN
# 2      NaN      NaN      NaN       NaN
# 3      NaN      NaN      NaN       NaN
# 4      NaN      NaN      NaN       NaN
#
# * Review NULL Data
# State                                  0
# Participation                          0
# Evidence-Based Reading and Writing     0
# Math                                   0
# Total                                  0
# Year                                   0
# Type                                   0
# Participation                         51
# Evidence-Based Reading and Writing    51
# English                               51
# Reading                               51
# Science                               51
# Composite                             51
# dtype: int64
#
# * Review data type
# State                                  object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# Year                                    int64
# Type                                   object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# English                               float64
# Reading                               float64
# Science                               float64
# Composite                              object
# dtype: object
# --------------------------------------------------------------------------------
#
# Year:2018, Type:SAT Shape:(51, 13)
# * Review Sample Data
#          State Participation  Evidence-Based Reading and Writing   Math  \
# 51     Alabama            6%                               595.0  571.0
# 52      Alaska           43%                               562.0  544.0
# 53     Arizona           29%                               577.0  572.0
# 54    Arkansas            5%                               592.0  576.0
# 55  California           60%                               540.0  536.0
#
#      Total  Year Type Participation  Evidence-Based Reading and Writing  \
# 51  1166.0  2018  SAT           NaN                                 NaN
# 52  1106.0  2018  SAT           NaN                                 NaN
# 53  1149.0  2018  SAT           NaN                                 NaN
# 54  1169.0  2018  SAT           NaN                                 NaN
# 55  1076.0  2018  SAT           NaN                                 NaN
#
#     English  Reading  Science Composite
# 51      NaN      NaN      NaN       NaN
# 52      NaN      NaN      NaN       NaN
# 53      NaN      NaN      NaN       NaN
# 54      NaN      NaN      NaN       NaN
# 55      NaN      NaN      NaN       NaN
#
# * Review NULL Data
# State                                  0
# Participation                          0
# Evidence-Based Reading and Writing     0
# Math                                   0
# Total                                  0
# Year                                   0
# Type                                   0
# Participation                         51
# Evidence-Based Reading and Writing    51
# English                               51
# Reading                               51
# Science                               51
# Composite                             51
# dtype: int64
#
# * Review data type
# State                                  object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# Year                                    int64
# Type                                   object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# English                               float64
# Reading                               float64
# Science                               float64
# Composite                              object
# dtype: object
# --------------------------------------------------------------------------------
#
# Year:2019, Type:SAT Shape:(53, 13)
# * Review Sample Data
#           State Participation  Evidence-Based Reading and Writing   Math  \
# 102     Alabama           NaN                                 NaN  560.0
# 103      Alaska           NaN                                 NaN  541.0
# 104     Arizona           NaN                                 NaN  565.0
# 105    Arkansas           NaN                                 NaN  559.0
# 106  California           NaN                                 NaN  531.0
#
#       Total  Year Type Participation  Evidence-Based Reading and Writing  \
# 102  1143.0  2019  SAT            7%                               583.0
# 103  1097.0  2019  SAT           41%                               556.0
# 104  1134.0  2019  SAT           31%                               569.0
# 105  1141.0  2019  SAT            6%                               582.0
# 106  1065.0  2019  SAT           63%                               534.0
#
#      English  Reading  Science Composite
# 102      NaN      NaN      NaN       NaN
# 103      NaN      NaN      NaN       NaN
# 104      NaN      NaN      NaN       NaN
# 105      NaN      NaN      NaN       NaN
# 106      NaN      NaN      NaN       NaN
#
# * Review NULL Data
# State                                  0
# Participation                         53
# Evidence-Based Reading and Writing    53
# Math                                   0
# Total                                  0
# Year                                   0
# Type                                   0
# Participation                          0
# Evidence-Based Reading and Writing     0
# English                               53
# Reading                               53
# Science                               53
# Composite                             53
# dtype: int64
#
# * Review data type
# State                                  object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# Year                                    int64
# Type                                   object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# English                               float64
# Reading                               float64
# Science                               float64
# Composite                              object
# dtype: object
# --------------------------------------------------------------------------------
#
# Year:2017, Type:ACT Shape:(52, 13)
# * Review Sample Data
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 155  National           60%                                 NaN  20.7    NaN
# 156   Alabama          100%                                 NaN  18.4    NaN
# 157    Alaska           65%                                 NaN  19.8    NaN
# 158   Arizona           62%                                 NaN  19.8    NaN
# 159  Arkansas          100%                                 NaN  19.0    NaN
#
#      Year Type Participation  Evidence-Based Reading and Writing  English  \
# 155  2017  ACT           NaN                                 NaN     20.3
# 156  2017  ACT           NaN                                 NaN     18.9
# 157  2017  ACT           NaN                                 NaN     18.7
# 158  2017  ACT           NaN                                 NaN     18.6
# 159  2017  ACT           NaN                                 NaN     18.9
#
#      Reading  Science Composite
# 155     21.4     21.0      21.0
# 156     19.7     19.4      19.2
# 157     20.4     19.9      19.8
# 158     20.1     19.8      19.7
# 159     19.7     19.5      19.4
#
# * Review NULL Data
# State                                  0
# Participation                          0
# Evidence-Based Reading and Writing    52
# Math                                   0
# Total                                 52
# Year                                   0
# Type                                   0
# Participation                         52
# Evidence-Based Reading and Writing    52
# English                                0
# Reading                                0
# Science                                0
# Composite                              0
# dtype: int64
#
# * Review data type
# State                                  object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# Year                                    int64
# Type                                   object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# English                               float64
# Reading                               float64
# Science                               float64
# Composite                              object
# dtype: object
# --------------------------------------------------------------------------------
#
# Year:2018, Type:ACT Shape:(52, 13)
# * Review Sample Data
#           State Participation  Evidence-Based Reading and Writing  Math  \
# 207     Alabama          100%                                 NaN   NaN
# 208      Alaska           33%                                 NaN   NaN
# 209     Arizona           66%                                 NaN   NaN
# 210    Arkansas          100%                                 NaN   NaN
# 211  California           27%                                 NaN   NaN
#
#      Total  Year Type Participation  Evidence-Based Reading and Writing  \
# 207    NaN  2018  ACT           NaN                                 NaN
# 208    NaN  2018  ACT           NaN                                 NaN
# 209    NaN  2018  ACT           NaN                                 NaN
# 210    NaN  2018  ACT           NaN                                 NaN
# 211    NaN  2018  ACT           NaN                                 NaN
#
#      English  Reading  Science Composite
# 207      NaN      NaN      NaN      19.1
# 208      NaN      NaN      NaN      20.8
# 209      NaN      NaN      NaN      19.2
# 210      NaN      NaN      NaN      19.4
# 211      NaN      NaN      NaN      22.7
#
# * Review NULL Data
# State                                  0
# Participation                          0
# Evidence-Based Reading and Writing    52
# Math                                  52
# Total                                 52
# Year                                   0
# Type                                   0
# Participation                         52
# Evidence-Based Reading and Writing    52
# English                               52
# Reading                               52
# Science                               52
# Composite                              0
# dtype: int64
#
# * Review data type
# State                                  object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# Year                                    int64
# Type                                   object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# English                               float64
# Reading                               float64
# Science                               float64
# Composite                              object
# dtype: object
# --------------------------------------------------------------------------------
#
# Year:2019, Type:ACT Shape:(52, 13)
# * Review Sample Data
#           State Participation  Evidence-Based Reading and Writing  Math  \
# 259     Alabama          100%                                 NaN   NaN
# 260      Alaska           38%                                 NaN   NaN
# 261     Arizona           73%                                 NaN   NaN
# 262    Arkansas          100%                                 NaN   NaN
# 263  California           23%                                 NaN   NaN
#
#      Total  Year Type Participation  Evidence-Based Reading and Writing  \
# 259    NaN  2019  ACT           NaN                                 NaN
# 260    NaN  2019  ACT           NaN                                 NaN
# 261    NaN  2019  ACT           NaN                                 NaN
# 262    NaN  2019  ACT           NaN                                 NaN
# 263    NaN  2019  ACT           NaN                                 NaN
#
#      English  Reading  Science Composite
# 259      NaN      NaN      NaN      18.9
# 260      NaN      NaN      NaN      20.1
# 261      NaN      NaN      NaN      19.0
# 262      NaN      NaN      NaN      19.3
# 263      NaN      NaN      NaN      22.6
#
# * Review NULL Data
# State                                  0
# Participation                          0
# Evidence-Based Reading and Writing    52
# Math                                  52
# Total                                 52
# Year                                   0
# Type                                   0
# Participation                         52
# Evidence-Based Reading and Writing    52
# English                               52
# Reading                               52
# Science                               52
# Composite                              0
# dtype: int64
#
# * Review data type
# State                                  object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# Year                                    int64
# Type                                   object
# Participation                          object
# Evidence-Based Reading and Writing    float64
# English                               float64
# Reading                               float64
# Science                               float64
# Composite                              object
# dtype: object
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Cleaning Data
# SAT 19 has difference column name, EBRW vs. Evidence-Based Reading and Writing

# %%
# SAT 2019 has difference column name, EBRW vs. Evidence-Based Reading and Writing
sat19_df.rename(columns={'EBRW': 'Evidence-Based Reading and Writing', 'Participation Rate': 'Participation'}, inplace=True)

# re-combine rename dataframe
exam_df = pd.concat([sat17_df, sat18_df, sat19_df, act17_df, act18_df, act19_df], ignore_index=True)
exam_df['Participation'] = pd.to_numeric(exam_df['Participation'].str.replace(r'—|%','', regex=True), errors='coerce')

# recheck null Participation
exam_df[exam_df['Participation'].isnull()]
exam_df['Participation'].isnull().sum()
# since it only 2 rows, we decide to drop these rows
exam_df = exam_df[~exam_df['Participation'].isna()]
# change Participation data type to int64
exam_df.loc[:, 'Participation'] = exam_df['Participation'].astype('int64')
#exam_df['Participation'] = exam_df['Participation'].astype('int64')

# mapping state with region
exam_df = exam_df.merge(state_region_df)

# %% [markdown]
# #### Formatting Data

# %%
# select 
exam_df.groupby(['Year','Type','Region'])['Participation'].describe()
# Out:
#                      count       mean        std   min    25%    50%     75%  \
# Year Type Region
# 2017 ACT  Midwest     12.0  77.833333  24.349102  29.0  71.50   82.0   98.50
#           Northeast    9.0  24.888889   8.237786   8.0  21.00   29.0   31.00
#           South       17.0  73.470588  31.965054  18.0  45.00  100.0  100.00
#           West        13.0  70.846154  29.042630  29.0  40.00   66.0  100.00
#      SAT  Midwest     12.0  17.250000  31.177279   2.0   3.00    3.0    9.75
#           Northeast    9.0  77.777778  15.114379  60.0  67.00   71.0   95.00
#           South       17.0  40.176471  36.435277   2.0   5.00   49.0   65.00
#           West        13.0  33.846154  27.257556   3.0  11.00   30.0   53.00
# 2018 ACT  Midwest     12.0  75.833333  29.151121  22.0  61.75   87.5  100.00
#           Northeast   10.0  19.800000   8.337332   7.0  15.25   22.0   25.75
#           South       16.0  75.062500  31.718488  17.0  51.00  100.0  100.00
#           West        13.0  62.615385  31.821215  24.0  33.00   66.0  100.00
#      SAT  Midwest     12.0  25.500000  38.587563   2.0   3.00    4.0   29.25
#           Northeast    9.0  85.222222  13.330208  64.0  79.00   82.0   97.00
#           South       17.0  41.117647  34.667857   3.0   6.00   52.0   68.00
#           West        13.0  43.153846  33.155809   3.0  16.00   43.0   60.00
# 2019 ACT  Midwest     12.0  72.416667  29.583344  19.0  58.25   78.5   97.00
#           Northeast    9.0  17.666667   6.020797   6.0  14.00   20.0   22.00
#           South       17.0  68.411765  33.706562  13.0  39.00   78.0  100.00
#           West        13.0  61.615385  32.076831  23.0  31.00   63.0  100.00
#      SAT  Midwest     12.0  25.916667  39.016217   2.0   3.00    4.0   30.75
#           Northeast    9.0  85.777778  13.169831  66.0  79.00   82.0   99.00
#           South       17.0  50.294118  39.164341   3.0   7.00   68.0   82.00
#           West        13.0  43.384615  33.402940   3.0  18.00   41.0   63.00
#
#                        max
# Year Type Region
# 2017 ACT  Midwest    100.0
#           Northeast   34.0
#           South      100.0
#           West       100.0
#      SAT  Midwest    100.0
#           Northeast  100.0
#           South      100.0
#           West        93.0
# 2018 ACT  Midwest    100.0
#           Northeast   31.0
#           South      100.0
#           West       100.0
#      SAT  Midwest    100.0
#           Northeast  100.0
#           South      100.0
#           West       100.0
# 2019 ACT  Midwest    100.0
#           Northeast   25.0
#           South      100.0
#           West       100.0
#      SAT  Midwest    100.0
#           Northeast  100.0
#           South      100.0
#           West       100.0

# %% [markdown]
# #### Visualization

# %%
# visualization code
